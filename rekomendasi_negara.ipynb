# %% [markdown]
# HELP International telah berhasil mengumpulkan sekitar $ 10 juta. Saat ini, CEO LSM perlu memutuskan bagaimana menggunakan uang ini secara strategis dan efektif. Jadi, CEO harus mengambil keputusan untuk memilih negara yang paling membutuhkan bantuan. Oleh karena itu, Tugas teman-teman  adalah mengkategorikan negara menggunakan beberapa faktor sosial ekonomi dan kesehatan yang menentukan perkembangan negara secara keseluruhan. Kemudian kalian perlu menyarankan negara mana saja  yang paling perlu menjadi fokus CEO.
# ---
# ## **Penjelasan kolom fitur:**
# ---
# **Negara** : Nama negara
#
# **Kematian_anak**: Kematian anak di bawah usia 5 tahun per 1000 kelahiran
#
# **Ekspor** : Ekspor barang dan jasa perkapita
#
# **Kesehatan**: Total pengeluaran kesehatan perkapita
#
# **Impor**: Impor barang dan jasa perkapita
#
# **Pendapatan**: Penghasilan bersih perorang
#
# **Inflasi**: Pengukuran tingkat pertumbuhan tahunan dari Total GDP
#
# **Harapan_hidup**: Jumlah tahun rata-rata seorang anak yang baru lahir akan hidup jika pola kematian saat ini tetap sama
#
# **Jumlah_fertiliti**: Jumlah anak yang akan lahir dari setiap wanita jika tingkat kesuburan usia saat ini tetap sama
#
# **GDPperkapita**: GDP per kapita. Dihitung sebagai Total GDP dibagi dengan total populasi.

# %%
# Ignore warnings
#import warnings
#warnings.filterwarnings('ignore')

# %% [markdown]
# - ## **import dataset**

# %%
#read csv
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('Data_Negara_HELP.csv')
df.head()
# Out:
#                 Negara  Kematian_anak  Ekspor  Kesehatan  Impor  Pendapatan  \
# 0          Afghanistan           90.2    10.0       7.58   44.9        1610
# 1              Albania           16.6    28.0       6.55   48.6        9930
# 2              Algeria           27.3    38.4       4.17   31.4       12900
# 3               Angola          119.0    62.3       2.85   42.9        5900
# 4  Antigua and Barbuda           10.3    45.5       6.03   58.9       19100
#
#    Inflasi  Harapan_hidup  Jumlah_fertiliti  GDPperkapita
# 0     9.44           56.2              5.82           553
# 1     4.49           76.3              1.65          4090
# 2    16.10           76.5              2.89          4460
# 3    22.40           60.1              6.16          3530
# 4     1.44           76.8              2.13         12200

# %% [markdown]
# - ## **Checking data**

# %%
df.shape
# Out:
# (167, 10)

# %%
df.nunique()
# Out:
# Negara              167
# Kematian_anak       139
# Ekspor              147
# Kesehatan           147
# Impor               151
# Pendapatan          156
# Inflasi             156
# Harapan_hidup       127
# Jumlah_fertiliti    138
# GDPperkapita        157
# dtype: int64

# %% [markdown]
# semua data negara unique.

# %%
df.describe()
# Out:
#        Kematian_anak      Ekspor   Kesehatan       Impor     Pendapatan  \
# count     167.000000  167.000000  167.000000  167.000000     167.000000
# mean       38.270060   41.108976    6.815689   46.890215   17144.688623
# std        40.328931   27.412010    2.746837   24.209589   19278.067698
# min         2.600000    0.109000    1.810000    0.065900     609.000000
# 25%         8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%        19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%        62.100000   51.350000    8.600000   58.750000   22800.000000
# max       208.000000  200.000000   17.900000  174.000000  125000.000000
#
#           Inflasi  Harapan_hidup  Jumlah_fertiliti   GDPperkapita
# count  167.000000     167.000000        167.000000     167.000000
# mean     7.781832      70.555689          2.947964   12964.155689
# std     10.570704       8.893172          1.513848   18328.704809
# ...

# %%
df.isna().sum()
# Out:
# Negara              0
# Kematian_anak       0
# Ekspor              0
# Kesehatan           0
# Impor               0
# Pendapatan          0
# Inflasi             0
# Harapan_hidup       0
# Jumlah_fertiliti    0
# GDPperkapita        0
# dtype: int64

# %% [markdown]
# tidak ada data null

# %%
df.dtypes
# Out:
# Negara               object
# Kematian_anak       float64
# Ekspor              float64
# Kesehatan           float64
# Impor               float64
# Pendapatan            int64
# Inflasi             float64
# Harapan_hidup       float64
# Jumlah_fertiliti    float64
# GDPperkapita          int64
# dtype: object

# %% [markdown]
# pendapatan dan GDP perkapita tipenya masih integer

# %%
df['Pendapatan'] = df['Pendapatan'].astype(float)
df['GDPperkapita'] = df['GDPperkapita'].astype(float)
df.dtypes
# Out:
# Negara               object
# Kematian_anak       float64
# Ekspor              float64
# Kesehatan           float64
# Impor               float64
# Pendapatan          float64
# Inflasi             float64
# Harapan_hidup       float64
# Jumlah_fertiliti    float64
# GDPperkapita        float64
# dtype: object

# %% [markdown]
# diubah ke float semua

# %% [markdown]
# - ## **Analisis Univariate**

# %%
# Visualize numerical columns with distribution plots
plt.figure(figsize=(16,14))

for i in enumerate(df.describe().columns):
  plt.subplot(3, 3, i[0]+1)
  sns.distplot(df[i[1]])
  plt.xticks(rotation=30)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df2 = df.sort_values(by=['GDPperkapita','Kesehatan', 'Pendapatan', 'Harapan_hidup', 'Kematian_anak'], 
                           ascending=[True, False, True, True, True])[['Negara', 'Kesehatan', 'Harapan_hidup',
                                                                       'Kematian_anak', 'Pendapatan', 'GDPperkapita']]

df2
#true=rendah
#false=tinggi
# Out:
#                Negara  Kesehatan  Harapan_hidup  Kematian_anak  Pendapatan  \
# 26            Burundi      11.60           57.7           93.6       764.0
# 88            Liberia      11.80           60.8           89.3       700.0
# 37   Congo, Dem. Rep.       7.91           57.5          116.0       609.0
# 112             Niger       5.16           58.8          123.0       814.0
# 132      Sierra Leone      13.10           55.0          160.0      1220.0
# ..                ...        ...            ...            ...         ...
# 44            Denmark      11.40           79.5            4.1     44000.0
# 123             Qatar       1.81           79.5            9.0    125000.0
# 145       Switzerland      11.50           82.2            4.5     55500.0
# 114            Norway       9.48           81.0            3.2     62300.0
# 91         Luxembourg       7.77           81.3            2.8     91700.0
#
#      GDPperkapita
# 26          231.0
# 88          327.0
# ...

# %% [markdown]
# Burundi, Liberia, Congo, Niger, dan Sierra Leone memiliki urutan teratas dengan GDP perkapita dan pendapatan yang kecil dan biaya kesehatan yang cukup besar.

# %% [markdown]
# - ## **Analisis Bivariate**

# %%
def bar_plotting(n, data, ycol, xcol, newtitle, x_label,new_color):
    plt.subplot(1, 2, n)
    sns.barplot(y=ycol, x=xcol, data=data, color=new_color)
    plt.title(newtitle)
    plt.xlabel(x_label)
    plt.ylabel(None)
    sns.despine(left=True)
    return

# %%
plt.figure(figsize=(16,14))
lr_df1 = df.nlargest(10, columns=['Kematian_anak'])
sm_df1 = df.nsmallest(10, columns=['Kematian_anak'])
bar_plotting(1, lr_df1, 'Negara', 'Kematian_anak', '10 Negara dengan Tingkat Kematian Tertinggi', 'Child Mortality', 'red')
bar_plotting(2, sm_df1, 'Negara', 'Kematian_anak', '10 Negara dengan Tingkat Kematian Terendah', 'Child Mortality', 'darkblue')
plt.tight_layout()
plt.savefig('tingkat kematian.png')
plt.show()

# %%
plt.figure(figsize=(16,14))
lr_df2 = df.nlargest(10, columns=['Ekspor'])
sm_df2 = df.nsmallest(10, columns=['Ekspor'])
bar_plotting(1, lr_df2, 'Negara', 'Ekspor', '10 Negara dengan Tingkat ekspor Tertinggi', 'Export', 'darkblue')
bar_plotting(2, sm_df2, 'Negara', 'Ekspor', '10 Negara dengan Tingkat ekspor Tertinggi', 'Export', 'red')
plt.tight_layout()
plt.savefig('tingkat ekspor.jpeg')
plt.show()

# %%
# Visualize top 15 country and bottom 15 country with highest health value
plt.figure(figsize=(16,14))
lr_df3 = df.nlargest(10, columns=['Kesehatan'])
sm_df3 = df.nsmallest(10, columns=['Kesehatan'])
bar_plotting(1, lr_df3, 'Negara', 'Kesehatan', '10 Negara dengan Pengeluaran Kesehatan Tertinggi', 'Health', 'darkblue')
bar_plotting(2, sm_df3, 'Negara', 'Kesehatan', '10 Negara dengan Pengeluaran Kesehatan Terendah', 'Health', 'red')
plt.tight_layout()
plt.savefig('tingkat pengeluaran kesehatan.jpeg')
plt.show()

# %%
plt.figure(figsize=(16,14))
lr_df4 = df.nlargest(10, columns=['Impor'])
sm_df4 = df.nsmallest(10, columns=['Impor'])
bar_plotting(1, lr_df4, 'Negara', 'Impor', '10 Negara dengan Tingkat Impor Tertinggi', 'Import', 'darkblue')
bar_plotting(2, sm_df4, 'Negara', 'Impor', '10 Negara dengan Tingkat Impor Terendah', 'Import', 'red')
plt.tight_layout()
plt.savefig('tingkat impor.jpeg')
plt.show()

# %%
plt.figure(figsize=(16,14))
lr_df5 = df.nlargest(15, columns=['Pendapatan'])
sm_df5 = df.nsmallest(15, columns=['Pendapatan'])
bar_plotting(1, lr_df5, 'Negara', 'Pendapatan', '10 Negara dengan Pendapatan Tertinggi', 'Income', 'darkblue')
bar_plotting(2, sm_df5, 'Negara', 'Pendapatan', '10 Negara dengan Pendapatan Terendah', 'Income', 'red')
plt.tight_layout()
plt.savefig('tingkat pendapatan.jpeg')
plt.show()

# %%
plt.figure(figsize=(16,14))
lr_df6 = df.nlargest(10, columns=['Harapan_hidup'])
sm_df6 = df.nsmallest(10, columns=['Harapan_hidup'])
bar_plotting(1, lr_df6, 'Negara', 'Harapan_hidup', '10 Negara dengan Tingkat Harapan Hidup Tertinggi', 'Life Expectancy', 'darkblue')
bar_plotting(2, sm_df6, 'Negara', 'Harapan_hidup', '10 Negara dengan Tingkat Harapan Hidup Terendah', 'Life Expectancy', 'red')
plt.tight_layout()
plt.savefig('tingkat harapan hidup.jpeg')
plt.show()

# %%
plt.figure(figsize=(16,14))
lr_df7 = df.nlargest(10, columns=['GDPperkapita'])
sm_df7 = df.nsmallest(10, columns=['GDPperkapita'])
bar_plotting(1, lr_df7, 'Negara', 'GDPperkapita', '10 Negara dengan Tingkat GDPP Tertinggi', 'GDPP', 'darkblue')
bar_plotting(2, sm_df7, 'Negara', 'GDPperkapita', '10 Negara dengan Tingkat GDPP Terendah', 'GDPP', 'red')
plt.tight_layout()
plt.savefig('tingkat GDPP.jpeg')
plt.show()

# %%
sns.set_theme('notebook', style='dark')
plt.style.use("dark_background")
sns.set_palette("bright")
pairplot_df2 = sns.pairplot(df2, vars=['GDPperkapita','Kesehatan', 'Pendapatan', 'Harapan_hidup', 'Kematian_anak'], palette = 'Reds')
plt.show()
plt.savefig('pairplot negara.jpeg')

# %%
plt.figure(figsize=(16,14))
sns.set_theme('notebook', style='white')
sns.heatmap(df.corr(), annot=True, fmt='.2g')
plt.tight_layout()
plt.show()
plt.savefig('heatmap negara.jpeg')

# %% [markdown]
# dari pairplot dan heatmap, dapat disimpulkan bahwa:
# - angka kematian anak, inflasi, dan jumlah fertiliti dengan GDP,  memiliki korelasi negatif. yang artinya apabila variabel x semakin tinggi, maka akan semakin rendah variabel y nya
# - semakin tinggi jumlah fertiliti, kematian anak, dan inflasi, maka semakin rendah angka harapan hidup (korelasi negatif)
# - semakin tinggi inflasi, maka semakin rendah angka harapan hidup dan kesehatannya
# - semakin tinggi angka kematian anak, inflasi, dan jumlah fertiliti, semakin rendah pula pendapatanya
# - semakin tinggi GDPP nya, maka semakin pula ekspor, impor, kesehatan, harapan hidup, dan pendapatannya
# - semakin tinggi angka harapan hidup, semakin tinggi pula kesehatan dan pendapatan.

# %% [markdown]
# - ## **Scaling data**

# %%
newdf = pd.DataFrame(data= df, columns=['GDPperkapita','Ekspor', 'Kesehatan', 'Impor', 
                                        'Pendapatan', 'Harapan_hidup', 'Kematian_anak'])

newdf
# Out:
#      GDPperkapita  Ekspor  Kesehatan  Impor  Pendapatan  Harapan_hidup  \
# 0           553.0    10.0       7.58   44.9      1610.0           56.2
# 1          4090.0    28.0       6.55   48.6      9930.0           76.3
# 2          4460.0    38.4       4.17   31.4     12900.0           76.5
# 3          3530.0    62.3       2.85   42.9      5900.0           60.1
# 4         12200.0    45.5       6.03   58.9     19100.0           76.8
# ..            ...     ...        ...    ...         ...            ...
# 162        2970.0    46.6       5.25   52.7      2950.0           63.0
# 163       13500.0    28.5       4.91   17.6     16500.0           75.4
# 164        1310.0    72.0       6.84   80.2      4490.0           73.1
# 165        1310.0    30.0       5.18   34.4      4480.0           67.5
# 166        1460.0    37.0       5.89   30.9      3280.0           52.0
#
#      Kematian_anak
# 0             90.2
# 1             16.6
# 2             27.3
# 3            119.0
# ...

# %%
import sklearn
from sklearn import preprocessing
#sc = 
sc = sklearn.preprocessing.StandardScaler()
#scaled_df = sc.fit_transform(newdf)
#scaled_df
scaledf = sc.fit_transform(newdf)
scaledf
# Out:
# array([[-0.67917961, -1.13827979,  0.27908825, ..., -0.8082454 ,
#         -1.61909203,  1.29153238],
#        [-0.48562324, -0.47965843, -0.09701618, ..., -0.3753689 ,
#          0.64786643, -0.5389489 ],
#        [-0.46537561, -0.09912164, -0.96607302, ..., -0.22084447,
#          0.67042323, -0.27283273],
#        ...,
#        [-0.63775406,  1.13030491,  0.0088773 , ..., -0.65840354,
#          0.28695762, -0.37231541],
#        [-0.63775406, -0.40647827, -0.59727159, ..., -0.65892382,
#         -0.34463279,  0.44841668],
#        [-0.62954556, -0.15034774, -0.33801514, ..., -0.72135793,
#         -2.09278484,  1.11495062]])

# %%
scaled_df = pd.DataFrame(scaledf, columns = newdf.columns)
display(scaled_df.head())
# Out:
#    GDPperkapita    Ekspor  Kesehatan     Impor  Pendapatan  Harapan_hidup  \
# 0     -0.679180 -1.138280   0.279088 -0.082455   -0.808245      -1.619092
# 1     -0.485623 -0.479658  -0.097016  0.070837   -0.375369       0.647866
# 2     -0.465376 -0.099122  -0.966073 -0.641762   -0.220844       0.670423
# 3     -0.516268  0.775381  -1.448071 -0.165315   -0.585043      -1.179234
# 4     -0.041817  0.160668  -0.286894  0.497568    0.101732       0.704258
#
#    Kematian_anak
# 0       1.291532
# 1      -0.538949
# 2      -0.272833
# 3       2.007808
# 4      -0.695634

# %% [markdown]
# - ## **Clustering data**

# %%
# To perform KMeans clustering 
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# membuat fungsi Elbow Method
sns.set_theme('notebook', style='white')
def elbowMethod(data, k_min=1, k_max= 8):
    wcss = [] # Within Cluster Sum of Squares
    k_range = range(k_min, k_max + 1)

    for i in k_range:
      kmeans_test = KMeans(n_clusters = i, random_state = 42, init = 'k-means++')
      kmeans_test.fit(data)
      wcss.append(kmeans_test.inertia_)

    fig, ax = plt.subplots(figsize=(15,8))
    ax.plot(k_range, wcss, marker='o')

    for i, value in enumerate(wcss):
        ax.text(i+2.15, value-0.005, round(value,3))

    plt.axvline(x = 4, color = 'r')
    plt.title('The Elbow Method')
    plt.xlabel('Number of clusters')
    plt.ylabel('WCSS')
    plt.show()

# %%
elbowMethod(scaled_df)

# %% [markdown]
# berarti banyaknya cluster ada 4

# %%
kmeans1 = KMeans(n_clusters = 4, random_state = 42).fit(scaled_df)
labels1 = kmeans1.labels_

# %%
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10)
    kmeans.fit(newdf)
    score.append(kmeans.inertia_)

# %%
print('n-cluster = 4')
print()
hasilcl = df.copy()
hasilcl['kmeans_4cluster'] = labels1
print('Cluster and its countries quantity :')
display(hasilcl.kmeans_4cluster.value_counts(ascending=True))
print()
display(hasilcl)
# Out:
# n-cluster = 4
#
# Cluster and its countries quantity :
# 2     3
# 3    29
# 1    50
# 0    85
# Name: kmeans_4cluster, dtype: int64
#                   Negara  Kematian_anak  Ekspor  Kesehatan  Impor  Pendapatan  \
# 0            Afghanistan           90.2    10.0       7.58   44.9      1610.0
# 1                Albania           16.6    28.0       6.55   48.6      9930.0
# 2                Algeria           27.3    38.4       4.17   31.4     12900.0
# 3                 Angola          119.0    62.3       2.85   42.9      5900.0
# 4    Antigua and Barbuda           10.3    45.5       6.03   58.9     19100.0
# ..                   ...            ...     ...        ...    ...         ...
# 162              Vanuatu           29.2    46.6       5.25   52.7      2950.0
# 163            Venezuela           17.1    28.5       4.91   17.6     16500.0
# 164              Vietnam           23.3    72.0       6.84   80.2      4490.0
# ...

# %%
import seaborn as sns
plt.figure(figsize=(8,12))
sns.set_theme('notebook', style='white')
sns.set_palette("bright")
g = sns.pairplot(hasilcl, hue="kmeans_4cluster", diag_kind="hist", corner=True, palette = 'bright')
plt.show()
plt.savefig('KMeans Negara.jpeg')

# %%
#rata-rata tiap cluster
analysis_res = hasilcl.groupby('kmeans_4cluster').agg({'mean'})
analysis_res['Banyak_negara'] = hasilcl.groupby('kmeans_4cluster')['Negara'].count()
display(analysis_res)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9920\347391713.py:2: FutureWarning: ['Negara'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   analysis_res = hasilcl.groupby('kmeans_4cluster').agg({'mean'})
#                 Kematian_anak      Ekspor Kesehatan       Impor    Pendapatan  \
#                          mean        mean      mean        mean          mean
# kmeans_4cluster
# 0                   19.791765   42.738824  6.389059   49.109412  13633.058824
# 1                   91.038000   27.579980  6.132800   40.809318   3703.060000
# 2                    4.133333  176.000000  6.793333  156.666667  64033.333333
# 3                    4.982759   45.703448  9.245862   39.513793  45762.068966
#
#                    Inflasi Harapan_hidup Jumlah_fertiliti  GDPperkapita  \
#                       mean          mean             mean          mean
# kmeans_4cluster
# ...

# %%
# Visualisasi 
plt.figure(figsize=(16, 14))
for i, var in enumerate(newdf.columns):
    plt.subplot(3,3,i+1)
    sns.barplot(x = analysis_res.reset_index().kmeans_4cluster, y = analysis_res[var]['mean'])
    plt.ylabel(var, fontsize=15)
    plt.xlabel('Cluster', fontsize=15)
plt.tight_layout()    
plt.show()

# %% [markdown]
# dari grafik bar diatas, dapat disimpulkan ciri-ciri dari masing-masing cluster:
# - cluster 1 memiliki tingkat GDPP, ekspor, impor, pendapatan, dan kematian anak rendah, namun tingkat harapan hidup dan kesehatan yang cukup tinggi.
# - cluster 2 memiliki tingkat GDPP, ekspor, impor, pendapatan rendah, namun tingkat kesehatan, harapan hidup, dan kematian anak yang sangat tinggi.
# - cluster 3 semua tinggi kecuali angka kematian anak ang rendah.
# - cluster 4 memiliki tingkat GDPP, kesehatan, harapan hidup, dan pendapatan tinggi, namun tingkat kematian anak, ekspor, dan impor yang rendah.

# %% [markdown]
# ## berdasarkan operasi pengerjaan sebelumnya, dapat disimpulkan bahwa cluster yang cocok adalah cluster ke-2

# %%
df3 = hasilcl.sort_values(by=['GDPperkapita','Kesehatan', 'Pendapatan', 'Harapan_hidup', 'Kematian_anak', 'kmeans_4cluster'], 
                           ascending=[True, True, True, False, True, True])[['Negara', 'Kesehatan', 'Harapan_hidup',
                                                                       'Kematian_anak', 'Pendapatan', 'GDPperkapita']]

df3.head(10)
#true=rendah
#false=tinggi
#dari jurnal, semakin tinggi pengeluaran kesehatan, makin bagus kualitas kesehatan di tempat tersebut
# Out:
#                        Negara  Kesehatan  Harapan_hidup  Kematian_anak  \
# 26                    Burundi      11.60           57.7           93.6
# 88                    Liberia      11.80           60.8           89.3
# 37           Congo, Dem. Rep.       7.91           57.5          116.0
# 112                     Niger       5.16           58.8          123.0
# 132              Sierra Leone      13.10           55.0          160.0
# 93                 Madagascar       3.77           60.8           62.2
# 106                Mozambique       5.21           54.5          101.0
# 31   Central African Republic       3.98           47.5          149.0
# 94                     Malawi       6.59           53.1           90.5
# 50                    Eritrea       2.66           61.7           55.2
#
#      Pendapatan  GDPperkapita
# 26        764.0         231.0
# 88        700.0         327.0
# 37        609.0         334.0
# 112       814.0         348.0
# 132      1220.0         399.0
# ...

# %%
#atau dengan cara berikut
finale = hasilcl[hasilcl['kmeans_4cluster']==1]

df4 = finale.sort_values(by=['GDPperkapita','Kesehatan', 'Pendapatan', 'Harapan_hidup', 'Kematian_anak'], 
                           ascending=[True, True, True, False, True])[['Negara', 'Kesehatan', 'Harapan_hidup',
                                                                       'Kematian_anak', 'Pendapatan', 'GDPperkapita']]

df4.head(10)
# Out:
#                        Negara  Kesehatan  Harapan_hidup  Kematian_anak  \
# 26                    Burundi      11.60           57.7           93.6
# 88                    Liberia      11.80           60.8           89.3
# 37           Congo, Dem. Rep.       7.91           57.5          116.0
# 112                     Niger       5.16           58.8          123.0
# 132              Sierra Leone      13.10           55.0          160.0
# 93                 Madagascar       3.77           60.8           62.2
# 106                Mozambique       5.21           54.5          101.0
# 31   Central African Republic       3.98           47.5          149.0
# 94                     Malawi       6.59           53.1           90.5
# 50                    Eritrea       2.66           61.7           55.2
#
#      Pendapatan  GDPperkapita
# 26        764.0         231.0
# 88        700.0         327.0
# 37        609.0         334.0
# 112       814.0         348.0
# 132      1220.0         399.0
# ...

# %% [markdown]
# dapat disimpulkan, bahwa negara diatas adalah negara-negara yang akan direkomendasikan untuk diberikan bantuan dari LSM
